# %%
#import fastai.vision.all and vision.widgets to create widgets
from fastai.vision.all import *
from fastai.vision.widgets import *

path = Path()
learn_inf = load_learner(path/'export.pkl', cpu=True)
#declare a button,output,label widget
btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
lbl_pred = widgets.Label()
#define an on_data_change function which execute when an image is #uploaded.It gets the image uploaded,display the image,make a #prediction of the image and output prediction, probability of #predictions
def on_data_change(change):    
    lbl_pred.value = ''     
    img = PILImage.create(btn_upload.data[-1])     
    out_pl.clear_output()     
    with out_pl: display(img.to_thumb(128,128))     
    pred,pred_idx,probs = learn_inf.predict(img)    
    lbl_pred.value = f'Prediction: {pred}; Probability:{probs[pred_idx]:.04f}'
#button to click to upload image
btn_upload.observe(on_data_change, names=['data'])
#display label,btn_upload,out_pl,lbl_pred vertically
display(VBox([widgets.Label('Select an Image of Plant!'), btn_upload, out_pl, lbl_pred]))
# Out:
# Cloning into 'fastai'...
# remote: Enumerating objects: 13539, done.
# remote: Total 13539 (delta 0), reused 0 (delta 0), pack-reused 13539
# Receiving objects: 100% (13539/13539), 625.06 MiB | 34.70 MiB/s, done.
# Resolving deltas: 100% (10639/10639), done.
# Obtaining file:///content/fastai
# Requirement already satisfied: pip in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (19.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (20.8)
# Collecting fastcore<1.4,>=1.3.8
#   Downloading https://files.pythonhosted.org/packages/0c/98/60404e2817cff113a6ae4023bc1772e23179408fdf7857fa410551758dfe/fastcore-1.3.19-py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 7.3MB/s
# Requirement already satisfied: torchvision<0.9,>=0.8 in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (0.8.1+cu101)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (3.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (1.1.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (2.23.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (3.13)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (1.0.0)
# Requirement already satisfied: pillow>6.0.0 in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (7.0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (1.4.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (2.2.4)
# Requirement already satisfied: torch<1.8,>=1.7.0 in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (1.7.0+cu101)
# Collecting nbdev<2,>=1.0.10
#   Downloading https://files.pythonhosted.org/packages/b7/81/7ae0d7f03a69601943b7f77216f014f0668286cf67ac7780b2351a962291/nbdev-1.1.12-py3-none-any.whl (46kB)
#      |████████████████████████████████| 51kB 7.6MB/s
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (7.6.3)
# Collecting pytorch-lightning
#   Downloading https://files.pythonhosted.org/packages/e9/ab/5e5e35884d09bc04ee0a48b6fe8451e7ba6840e3df9052dbdb85c9a947a7/pytorch_lightning-1.1.5-py3-none-any.whl (685kB)
#      |████████████████████████████████| 686kB 36.2MB/s
# Collecting pytorch-ignite
#   Downloading https://files.pythonhosted.org/packages/14/98/0a5b83d82ff245d3de5f09808fb80ff0ed03f6b10933979e6018b1dd0eaa/pytorch_ignite-0.4.2-py2.py3-none-any.whl (175kB)
#      |████████████████████████████████| 184kB 55.2MB/s
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/88/b1/41130a228dd656a1a31ba281598a968320283f48d42782845f6ba567f00b/transformers-4.2.2-py3-none-any.whl (1.8MB)
#      |████████████████████████████████| 1.8MB 54.9MB/s
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/14/67/e42bd1181472c95c8cda79305df848264f2a7f62740995a46945d9797b67/sentencepiece-0.1.95-cp36-cp36m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 59.0MB/s
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (2.4.0)
# Collecting pydicom
#   Downloading https://files.pythonhosted.org/packages/f4/15/df16546bc59bfca390cf072d473fb2c8acd4231636f64356593a63137e55/pydicom-2.1.2-py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 55.8MB/s
# Collecting catalyst
#   Downloading https://files.pythonhosted.org/packages/b7/8b/03a94e9943885ac39f11b46932ea51542812a78a901cc631d0a0348bcbd0/catalyst-20.12-py2.py3-none-any.whl (490kB)
#      |████████████████████████████████| 491kB 59.9MB/s
# Collecting captum>=0.3
#   Downloading https://files.pythonhosted.org/packages/13/b0/8fa3ab89e2e37c960cdd09595fa911fbb8d6da216c8bc98e18c858a0128d/captum-0.3.1-py3-none-any.whl (4.4MB)
#      |████████████████████████████████| 4.4MB 54.8MB/s
# Requirement already satisfied: flask in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (1.1.2)
# Collecting wandb
#   Downloading https://files.pythonhosted.org/packages/b3/fe/9698a355bd53757f00d535df18deb951c089188a9a9baaadc73ddfcbe043/wandb-0.10.15-py2.py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 51.0MB/s
# Collecting kornia
#   Downloading https://files.pythonhosted.org/packages/25/f6/9fb4cc2c67796680c8041fa6ffdee5f280e4cf65c86835768a700a324d59/kornia-0.4.1-py2.py3-none-any.whl (225kB)
#      |████████████████████████████████| 225kB 62.9MB/s
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (0.16.2)
# Collecting neptune-client
#   Downloading https://files.pythonhosted.org/packages/8a/d0/fd7675a5c7d634859dd3144b0108dd1ac918a14322e700351e7b815488ad/neptune-client-0.4.133.tar.gz (110kB)
#      |████████████████████████████████| 112kB 52.9MB/s
# Requirement already satisfied: albumentations in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (0.1.12)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (4.1.2.30)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.6/dist-packages (from fastai==2.2.4) (0.14.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->fastai==2.2.4) (2.4.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision<0.9,>=0.8->fastai==2.2.4) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->fastai==2.2.4) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->fastai==2.2.4) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->fastai==2.2.4) (0.10.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->fastai==2.2.4) (2018.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->fastai==2.2.4) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->fastai==2.2.4) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->fastai==2.2.4) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->fastai==2.2.4) (3.0.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->fastai==2.2.4) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.2.4) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.2.4) (2.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.2.4) (0.8.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.2.4) (3.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.2.4) (4.41.1)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.2.4) (7.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.2.4) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.2.4) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.2.4) (0.4.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.2.4) (1.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy->fastai==2.2.4) (51.3.3)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch<1.8,>=1.7.0->fastai==2.2.4) (0.8)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch<1.8,>=1.7.0->fastai==2.2.4) (0.16.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch<1.8,>=1.7.0->fastai==2.2.4) (3.7.4.3)
# Requirement already satisfied: nbconvert<6 in /usr/local/lib/python3.6/dist-packages (from nbdev<2,>=1.0.10->fastai==2.2.4) (5.6.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from nbdev<2,>=1.0.10->fastai==2.2.4) (5.3.5)
# Requirement already satisfied: nbformat>=4.4.0 in /usr/local/lib/python3.6/dist-packages (from nbdev<2,>=1.0.10->fastai==2.2.4) (5.0.8)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.6/dist-packages (from nbdev<2,>=1.0.10->fastai==2.2.4) (1.0.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from nbdev<2,>=1.0.10->fastai==2.2.4) (4.10.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets->fastai==2.2.4) (4.3.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets->fastai==2.2.4) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /usr/local/lib/python3.6/dist-packages (from ipywidgets->fastai==2.2.4) (5.5.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /usr/local/lib/python3.6/dist-packages (from ipywidgets->fastai==2.2.4) (1.0.0)
# Collecting fsspec[http]>=0.8.1
#   Downloading https://files.pythonhosted.org/packages/ec/80/72ac0982cc833945fada4b76c52f0f65435ba4d53bc9317d1c70b5f7e7d5/fsspec-0.8.5-py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 12.6MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers->fastai==2.2.4) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers->fastai==2.2.4) (2019.12.20)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 48.1MB/s
# Collecting tokenizers==0.9.4
#   Downloading https://files.pythonhosted.org/packages/0f/1c/e789a8b12e28be5bc1ce2156cf87cb522b379be9cadc7ad8091a4cc107c4/tokenizers-0.9.4-cp36-cp36m-manylinux2010_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 45.0MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from transformers->fastai==2.2.4) (3.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->fastai==2.2.4) (1.15.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->fastai==2.2.4) (3.12.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard->fastai==2.2.4) (1.0.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard->fastai==2.2.4) (0.36.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard->fastai==2.2.4) (3.3.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->fastai==2.2.4) (1.7.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard->fastai==2.2.4) (0.4.2)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard->fastai==2.2.4) (1.32.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard->fastai==2.2.4) (1.17.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.6/dist-packages (from tensorboard->fastai==2.2.4) (0.10.0)
# Collecting tensorboardX>=2.1.0
#   Downloading https://files.pythonhosted.org/packages/af/0c/4f41bcd45db376e6fe5c619c01100e9b7531c55791b7244815bac6eac32c/tensorboardX-2.1-py2.py3-none-any.whl (308kB)
#      |████████████████████████████████| 317kB 56.6MB/s
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from flask->fastai==2.2.4) (2.11.2)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from flask->fastai==2.2.4) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from flask->fastai==2.2.4) (1.1.0)
# Collecting sentry-sdk>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/b1/5c/018bf9a5c24343a664deaea70e61f33f53bb1bd3caf193110f827bfd07e2/sentry_sdk-0.19.5-py2.py3-none-any.whl (128kB)
#      |████████████████████████████████| 133kB 56.8MB/s
# Collecting watchdog<0.10.5,>=0.8.3
#   Downloading https://files.pythonhosted.org/packages/6f/10/500580a0987363a0d9e1f3dd5cb1bba94a47e19266c6ce9dfb6cdd455758/watchdog-0.10.4.tar.gz (98kB)
#      |████████████████████████████████| 102kB 13.2MB/s
# Collecting GitPython>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/d7/cb/ec98155c501b68dcb11314c7992cd3df6dce193fd763084338a117967d53/GitPython-3.1.12-py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 52.2MB/s
# Collecting configparser>=3.8.1
#   Downloading https://files.pythonhosted.org/packages/08/b2/ef713e0e67f6e7ec7d59aea3ee78d05b39c15930057e724cc6d362a8c3bb/configparser-5.0.1-py3-none-any.whl
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.6/dist-packages (from wandb->fastai==2.2.4) (2.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb->fastai==2.2.4) (5.4.8)
# Collecting docker-pycreds>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Collecting subprocess32>=3.5.3
#   Downloading https://files.pythonhosted.org/packages/32/c8/564be4d12629b912ea431f1a50eb8b3b9d00f1a0b1ceff17f266be190007/subprocess32-3.5.4.tar.gz (97kB)
#      |████████████████████████████████| 102kB 12.6MB/s
# Collecting shortuuid>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/25/a6/2ecc1daa6a304e7f1b216f0896b26156b78e7c38e1211e9b798b4716c53d/shortuuid-1.0.1-py3-none-any.whl
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->fastai==2.2.4) (2.4.1)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->fastai==2.2.4) (2.5)
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->fastai==2.2.4) (1.1.1)
# Collecting bravado
#   Downloading https://files.pythonhosted.org/packages/6d/3d/f8772d9295c03e08a9ab4afc1ccd195efe6cb4d1af3135b7f74eb8beb0d6/bravado-11.0.2-py2.py3-none-any.whl
# Requirement already satisfied: oauthlib>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from neptune-client->fastai==2.2.4) (3.1.0)
# Collecting PyJWT
#   Downloading https://files.pythonhosted.org/packages/b4/9b/8850f99027ed029af6828199cc87179eaccbbf1f9e6e373e7f0177d32dad/PyJWT-2.0.1-py3-none-any.whl
# Requirement already satisfied: requests-oauthlib>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from neptune-client->fastai==2.2.4) (1.3.0)
# Collecting websocket-client>=0.35.0
#   Downloading https://files.pythonhosted.org/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl (200kB)
#      |████████████████████████████████| 204kB 50.7MB/s
# Collecting imgaug<0.2.7,>=0.2.5
#   Downloading https://files.pythonhosted.org/packages/ad/2e/748dbb7bb52ec8667098bae9b585f448569ae520031932687761165419a2/imgaug-0.2.6.tar.gz (631kB)
#      |████████████████████████████████| 634kB 46.9MB/s
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert<6->nbdev<2,>=1.0.10->fastai==2.2.4) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert<6->nbdev<2,>=1.0.10->fastai==2.2.4) (0.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert<6->nbdev<2,>=1.0.10->fastai==2.2.4) (0.6.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert<6->nbdev<2,>=1.0.10->fastai==2.2.4) (3.2.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from nbconvert<6->nbdev<2,>=1.0.10->fastai==2.2.4) (2.6.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert<6->nbdev<2,>=1.0.10->fastai==2.2.4) (1.4.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbconvert<6->nbdev<2,>=1.0.10->fastai==2.2.4) (4.7.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert<6->nbdev<2,>=1.0.10->fastai==2.2.4) (0.4.4)
# Requirement already satisfied: tornado>=4.1 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->nbdev<2,>=1.0.10->fastai==2.2.4) (5.1.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->nbdev<2,>=1.0.10->fastai==2.2.4) (20.0.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.4.0->nbdev<2,>=1.0.10->fastai==2.2.4) (2.6.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.4.0->nbdev<2,>=1.0.10->fastai==2.2.4) (0.2.0)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.6/dist-packages (from jupyter->nbdev<2,>=1.0.10->fastai==2.2.4) (5.0.1)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.6/dist-packages (from jupyter->nbdev<2,>=1.0.10->fastai==2.2.4) (5.2.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.6/dist-packages (from jupyter->nbdev<2,>=1.0.10->fastai==2.2.4) (5.3.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.3.1->ipywidgets->fastai==2.2.4) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->fastai==2.2.4) (0.7.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->fastai==2.2.4) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->fastai==2.2.4) (0.8.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->fastai==2.2.4) (1.0.18)
# Collecting aiohttp; extra == "http"
#   Downloading https://files.pythonhosted.org/packages/ad/e6/d4b6235d776c9b33f853e603efede5aac5a34f71ca9d3877adb30492eb4e/aiohttp-3.7.3-cp36-cp36m-manylinux2014_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 46.7MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->transformers->fastai==2.2.4) (3.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard->fastai==2.2.4) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard->fastai==2.2.4) (4.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard->fastai==2.2.4) (4.6)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->flask->fastai==2.2.4) (1.1.1)
# Collecting pathtools>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/e7/7f/470d6fcdf23f9f3518f6b0b76be9df16dcc8630ad409947f8be2eb0ed13a/pathtools-0.1.2.tar.gz
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 10.3MB/s
# Requirement already satisfied: msgpack in /usr/local/lib/python3.6/dist-packages (from bravado->neptune-client->fastai==2.2.4) (1.0.2)
# Collecting monotonic
#   Downloading https://files.pythonhosted.org/packages/ac/aa/063eca6a416f397bd99552c534c6d11d57f58f2e94c14780f3bbf818c4cf/monotonic-1.5-py2.py3-none-any.whl
# Collecting bravado-core>=5.16.1
#   Downloading https://files.pythonhosted.org/packages/76/11/18e9d28a156c33f2d5f15a5e155dc7130250acb0a569255a2b6b307b596d/bravado_core-5.17.0-py2.py3-none-any.whl (67kB)
#      |████████████████████████████████| 71kB 10.1MB/s
# Collecting simplejson
#   Downloading https://files.pythonhosted.org/packages/73/96/1e6b19045375890068d7342cbe280dd64ae73fd90b9735b5efb8d1e044a1/simplejson-3.17.2-cp36-cp36m-manylinux2010_x86_64.whl (127kB)
#      |████████████████████████████████| 133kB 52.1MB/s
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert<6->nbdev<2,>=1.0.10->fastai==2.2.4) (0.5.1)
# Requirement already satisfied: qtpy in /usr/local/lib/python3.6/dist-packages (from qtconsole->jupyter->nbdev<2,>=1.0.10->fastai==2.2.4) (1.9.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->nbdev<2,>=1.0.10->fastai==2.2.4) (0.9.2)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->nbdev<2,>=1.0.10->fastai==2.2.4) (1.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->fastai==2.2.4) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->fastai==2.2.4) (0.2.5)
# Collecting idna-ssl>=1.0; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/46/03/07c4894aae38b0de52b52586b24bf189bb83e4ddabfe2e2c8f2419eec6f4/idna-ssl-1.1.0.tar.gz
# Collecting async-timeout<4.0,>=3.0
#   Downloading https://files.pythonhosted.org/packages/e1/1e/5a4441be21b0726c4464f3f23c8b19628372f606755a9d2e46c187e65ec4/async_timeout-3.0.1-py3-none-any.whl
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp; extra == "http"->fsspec[http]>=0.8.1->pytorch-lightning->fastai==2.2.4) (20.3.0)
# Collecting multidict<7.0,>=4.5
#   Downloading https://files.pythonhosted.org/packages/a1/35/b22524d6b9cacfb4c5eff413a069bbc17c6ea628e54da5c6c989998ced5f/multidict-5.1.0-cp36-cp36m-manylinux2014_x86_64.whl (141kB)
#      |████████████████████████████████| 143kB 57.7MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/da/08/52b26b44bce7b818b410aee37c5e424c9ea420c557bca97dc2adac29b151/yarl-1.6.3-cp36-cp36m-manylinux2014_x86_64.whl (293kB)
#      |████████████████████████████████| 296kB 58.1MB/s
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard->fastai==2.2.4) (0.4.8)
# Collecting smmap<4,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/d5/1e/6130925131f639b2acde0f7f18b73e33ce082ff2d90783c436b52040af5a/smmap-3.0.5-py2.py3-none-any.whl
# Collecting swagger-spec-validator>=2.0.1
#   Downloading https://files.pythonhosted.org/packages/09/de/e78cefbf5838b434b63a789264b79821cb2267f1498fbed23ef8590133e4/swagger_spec_validator-2.7.3-py2.py3-none-any.whl
# Collecting jsonref
#   Downloading https://files.pythonhosted.org/packages/07/92/f8e4ac824b14af77e613984e480fa818397c72d4141fc466decb26752749/jsonref-0.2-py3-none-any.whl
# Building wheels for collected packages: neptune-client, sacremoses, watchdog, subprocess32, imgaug, pathtools, idna-ssl
#   Building wheel for neptune-client (setup.py) ... done
#   Created wheel for neptune-client: filename=neptune_client-0.4.133-py2.py3-none-any.whl size=166465 sha256=ed54956fa506244759a7e66478811c44afd312189e882c44804bc8bd8f7a3d53
#   Stored in directory: /root/.cache/pip/wheels/29/45/fa/bcf7915b1eeb62055112810a107469239461bbfce25d9fbc06
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=8f8a9eeb00eee994159127941b1ebf6442a0c2471ff9636a5d52126ae46400e8
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
#   Building wheel for watchdog (setup.py) ... done
#   Created wheel for watchdog: filename=watchdog-0.10.4-cp36-none-any.whl size=74842 sha256=9976aeeae4f8256c067802ca31abccde0b5021920864f401292772c883d1c459
#   Stored in directory: /root/.cache/pip/wheels/9e/11/04/5160b8815b0cc7cf574bdc6d053e510169ec264c8791b4ec3a
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-cp36-none-any.whl size=6490 sha256=691058d66b3a9f221c47f52579983325f6de4a49f3e24d1a2924b3e243d60f1e
#   Stored in directory: /root/.cache/pip/wheels/68/39/1a/5e402bdfdf004af1786c8b853fd92f8c4a04f22aad179654d1
#   Building wheel for imgaug (setup.py) ... done
#   Created wheel for imgaug: filename=imgaug-0.2.6-cp36-none-any.whl size=654020 sha256=2ad80096b7cbd5d82393c4f9b26dcec4e6e0b9330832a7facac5cc6449f91c9c
#   Stored in directory: /root/.cache/pip/wheels/97/ec/48/0d25896c417b715af6236dbcef8f0bed136a1a5e52972fc6d0
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-cp36-none-any.whl size=8785 sha256=e94310d3f5fde645e4c17c3b5489548fc325c1161ce8cf0b83f0106663b99f9b
#   Stored in directory: /root/.cache/pip/wheels/0b/04/79/c3b0c3a0266a3cb4376da31e5bfe8bba0c489246968a68e843
#   Building wheel for idna-ssl (setup.py) ... done
#   Created wheel for idna-ssl: filename=idna_ssl-1.1.0-cp36-none-any.whl size=3163 sha256=8a59ecd396b54971a1093133434a8d579c1cc40fab48af94e23ba9d90c159d35
#   Stored in directory: /root/.cache/pip/wheels/d3/00/b3/32d613e19e08a739751dd6bf998cfed277728f8b2127ad4eb7
# Successfully built neptune-client sacremoses watchdog subprocess32 imgaug pathtools idna-ssl
# ERROR: pytorch-lightning 1.1.5 has requirement future>=0.17.1, but you'll have future 0.16.0 which is incompatible.
# ERROR: pytorch-lightning 1.1.5 has requirement PyYAML>=5.1, but you'll have pyyaml 3.13 which is incompatible.
# ERROR: neptune-client 0.4.133 has requirement future>=0.17.1, but you'll have future 0.16.0 which is incompatible.
# Installing collected packages: fastcore, nbdev, idna-ssl, async-timeout, multidict, yarl, aiohttp, fsspec, pytorch-lightning, pytorch-ignite, sacremoses, tokenizers, transformers, sentencepiece, pydicom, tensorboardX, catalyst, captum, sentry-sdk, pathtools, watchdog, smmap, gitdb, GitPython, configparser, docker-pycreds, subprocess32, shortuuid, wandb, kornia, monotonic, swagger-spec-validator, simplejson, jsonref, bravado-core, bravado, PyJWT, websocket-client, neptune-client, fastai, imgaug
#   Found existing installation: fastai 1.0.61
#     Uninstalling fastai-1.0.61:
#       Successfully uninstalled fastai-1.0.61
#   Running setup.py develop for fastai
#   Found existing installation: imgaug 0.2.9
#     Uninstalling imgaug-0.2.9:
#       Successfully uninstalled imgaug-0.2.9
# Successfully installed GitPython-3.1.12 PyJWT-2.0.1 aiohttp-3.7.3 async-timeout-3.0.1 bravado-11.0.2 bravado-core-5.17.0 captum-0.3.1 catalyst-20.12 configparser-5.0.1 docker-pycreds-0.4.0 fastai fastcore-1.3.19 fsspec-0.8.5 gitdb-4.0.5 idna-ssl-1.1.0 imgaug-0.2.6 jsonref-0.2 kornia-0.4.1 monotonic-1.5 multidict-5.1.0 nbdev-1.1.12 neptune-client-0.4.133 pathtools-0.1.2 pydicom-2.1.2 pytorch-ignite-0.4.2 pytorch-lightning-1.1.5 sacremoses-0.0.43 sentencepiece-0.1.95 sentry-sdk-0.19.5 shortuuid-1.0.1 simplejson-3.17.2 smmap-3.0.5 subprocess32-3.5.4 swagger-spec-validator-2.7.3 tensorboardX-2.1 tokenizers-0.9.4 transformers-4.2.2 wandb-0.10.15 watchdog-0.10.4 websocket-client-0.57.0 yarl-1.6.3
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-df80f640015a> in <module>()
#       3 get_ipython().system('pip install -e "fastai[dev]"')
#       4
# ----> 5 from fastai.vision.all import *
#       6 from fastai.vision.widgets import *
#       7
#
# ModuleNotFoundError: No module named 'fastai.vision'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
